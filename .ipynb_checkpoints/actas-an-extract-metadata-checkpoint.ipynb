# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import glob

# %%
from skimage.transform import resize
from libs import utils

# %%
path = "/home/actas/*.jpg"

# %%
# Only the cv proccessed actas

images_list = glob.glob(path)
print(len(images_list))
# Out:
# 33068

# %%
sample = images_list[:1000]

# %%
def read_dataframe(filenames_list, samples):
    
    imgs = []
    # Read every filename as an RGB image
    for fname in filenames_list[:samples]:
        try:
            imgs.append(plt.imread(fname)[..., :3])
        except Exception as e:
            print(e)
        
    # Crop every image to a square
    imgs_or = [utils.imcrop_tosquare(img_i) for img_i in imgs]

    # Then resize the square image to 100 x 100 pixels
    imgs = [resize(img_i, (100, 100)) for img_i in imgs_or]

    # Finally make our list of 3-D images a 4-D array with the first dimension the number of images:
    imgs = np.array(imgs).astype(np.float32)

    print(imgs.shape)
    
    return imgs

# %%
imgs = read_dataframe(sample, 100)
# Out:
# cannot identify image file '/home/actas/222941.jpg'
# cannot identify image file '/home/actas/504391.jpg'
# cannot identify image file '/home/actas/10571.jpg'
# (97, 100, 100, 3)

# %%
# Plot the resulting dataset:
# Make sure you "run" this cell after you create your `imgs` variable as a 4-D array!
# Make sure we have a 100 x 100 x 100 x 3 dimension array
assert(imgs.shape == (97, 100, 100, 3))
plt.figure(figsize=(10, 10))
plt.imshow(utils.montage(imgs, saveto='dataset_p_actas.png'))

# %%
"""
 CV_IO_utils.py  (author: Anson Wong / git: ankonzoid)
"""
import os
import skimage.io
from multiprocessing import Pool

# Read image
def read_img(filePath):
    return skimage.io.imread(filePath, as_gray=False)

# Read images with common extensions from a directory
def read_imgs_dir(dirPath, extensions, parallel=True):
    args = [os.path.join(dirPath, filename)
            for filename in os.listdir(dirPath)
            if any(filename.lower().endswith(ext) for ext in extensions)]
    if parallel:
        pool = Pool()
        imgs = pool.map(read_img, args)
        pool.close()
        pool.join()
    else:
        imgs = [read_img(arg) for arg in args]
    return imgs

# Save image to file
def save_img(filePath, img):
    skimage.io.imsave(filePath, img)
    
"""
 CV_plot_utils.py  (author: Anson Wong / git: ankonzoid)
"""
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from sklearn import manifold

# Plot image
def plot_img(img, range=[0, 255]):
    plt.imshow(img, vmin=range[0], vmax=range[1])
    plt.xlabel("xpixels")
    plt.ylabel("ypixels")
    plt.tight_layout()
    plt.show()
    plt.close()

# Plots images in 2 rows: top row is query, bottom row is answer
def plot_query_retrieval(img_query, imgs_retrieval, outFile):
    n_retrieval = len(imgs_retrieval)
    fig = plt.figure(figsize=(2*n_retrieval, 4))
    fig.suptitle("Image Retrieval (k={})".format(n_retrieval), fontsize=25)

    # Plot query image
    ax = plt.subplot(2, n_retrieval, 0 + 1)
    plt.imshow(img_query)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(4)  # increase border thickness
        ax.spines[axis].set_color('black')  # set to black
    ax.set_title("query",  fontsize=14)  # set subplot title

    # Plot retrieval images
    for i, img in enumerate(imgs_retrieval):
        ax = plt.subplot(2, n_retrieval, n_retrieval + i + 1)
        plt.imshow(img)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        for axis in ['top', 'bottom', 'left', 'right']:
            ax.spines[axis].set_linewidth(1)  # set border thickness
            ax.spines[axis].set_color('black')  # set to black
        ax.set_title("Rank #%d" % (i+1), fontsize=14)  # set subplot title

    if outFile is None:
        plt.show()
    else:
        plt.savefig(outFile, bbox_inches='tight')
    plt.close()

# Plot t-SNE of images
def plot_tsne(X, imgs, outFile):

    def imscatter(x, y, images, ax=None, zoom=1.0):
        if ax is None:
            ax = plt.gca()
        x, y = np.atleast_1d(x, y)
        artists = []
        for x0, y0, img0 in zip(x, y, images):
            im = OffsetImage(img0, zoom=zoom)
            ab = AnnotationBbox(im, (x0, y0), xycoords='data', frameon=True)
            artists.append(ax.add_artist(ab))
        ax.update_datalim(np.column_stack([x, y]))
        ax.autoscale()
        return artists

    def plot_embedding(X, imgs, title=None):
        x_min, x_max = np.min(X, 0), np.max(X, 0)
        X = (X - x_min) / (x_max - x_min)

        plt.figure()
        ax = plt.subplot(111)
        for i in range(X.shape[0]):
            plt.text(X[i, 0], X[i, 1], ".", fontdict={'weight': 'bold', 'size': 9})
        if hasattr(offsetbox, 'AnnotationBbox'):
            imscatter(X[:,0], X[:,1], imgs, zoom=0.3, ax=ax)

        plt.xticks([]), plt.yticks([])
        if title is not None:
            plt.title(title, fontsize=18)

    tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
    X_tsne = tsne.fit_transform(X)
    plot_embedding(X_tsne, imgs, "t-SNE embeddings")
    if outFile is None:
        plt.show()
    else:
        plt.savefig(outFile, bbox_inches='tight')
    plt.close()

# Plot image reconstructions
def plot_reconstructions(imgs, imgs_reconstruct, outFile,
                         range_imgs=[0, 255],
                         range_imgs_reconstruct=[0, 1]):
    # Create plot to save
    assert len(imgs) == len(imgs_reconstruct)
    fig = plt.figure(figsize=(20, 4))
    fig.suptitle("Image Reconstructions", fontsize=35)
    n = min(len(imgs), 10)
    for i in range(n):

        # Plot original image
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(imgs[i],
                   vmin=range_imgs[0],
                   vmax=range_imgs[1])
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Plot reconstructed image
        ax = plt.subplot(2, n, n + i + 1)
        plt.imshow(imgs_reconstruct[i],
                   vmin=range_imgs_reconstruct[0],
                   vmax=range_imgs_reconstruct[1])
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    if outFile is None:
        plt.show()
    else:
        plt.savefig(outFile, bbox_inches='tight')
    plt.close()
    
"""
 CV_transform_utils.py  (author: Anson Wong / git: ankonzoid)
"""
from multiprocessing import Pool
from skimage.transform import resize

# Apply transformations to multiple images
def apply_transformer(imgs, transformer, parallel=True):
    if parallel:
        pool = Pool()
        imgs_transform = pool.map(transformer, [img for img in imgs])
        pool.close()
        pool.join()
    else:
        imgs_transform = [transformer(img) for img in imgs]
    return imgs_transform

# Normalize image data [0, 255] -> [0.0, 1.0]
def normalize_img(img):
    return img / 255.

# Resize image
def resize_img(img, shape_resized):
    img_resized = resize(img, shape_resized,
                         anti_aliasing=True,
                         preserve_range=True)
    assert img_resized.shape == shape_resized
    return img_resized

# Flatten image
def flatten_img(img):
    return img.flatten("C")


"""
 autoencoder.py  (author: Anson Wong / git: ankonzoid)
"""
import numpy as np
import tensorflow as tf

class AutoEncoder():

    def __init__(self, modelName, info):
        self.modelName = modelName
        self.info = info
        self.autoencoder = None
        self.encoder = None
        self.decoder = None

    # Train
    def fit(self, X, n_epochs=50, batch_size=256):
        indices_fracs = split(fracs=[0.9, 0.1], N=len(X), seed=0)
        X_train, X_valid = X[indices_fracs[0]], X[indices_fracs[1]]
        self.autoencoder.fit(X_train, X_train,
                             epochs = n_epochs,
                             batch_size = batch_size,
                             shuffle = True,
                             validation_data = (X_valid, X_valid))

    # Inference
    def predict(self, X):
        return self.encoder.predict(X)

    # Set neural network architecture
    def set_arch(self):

        shape_img = self.info["shape_img"]
        shape_img_flattened = (np.prod(list(shape_img)),)

        # Set encoder and decoder graphs
        if self.modelName == "simpleAE":
            encode_dim = 128

            input = tf.keras.Input(shape=shape_img_flattened)
            encoded = tf.keras.layers.Dense(encode_dim, activation='relu')(input)

            decoded = tf.keras.layers.Dense(shape_img_flattened[0], activation='sigmoid')(encoded)

        elif self.modelName == "convAE":
            n_hidden_1, n_hidden_2, n_hidden_3 = 16, 8, 8
            convkernel = (3, 3)  # convolution kernel
            poolkernel = (2, 2)  # pooling kernel

            input = tf.keras.layers.Input(shape=shape_img)
            x = tf.keras.layers.Conv2D(n_hidden_1, convkernel, activation='relu', padding='same')(input)
            x = tf.keras.layers.MaxPooling2D(poolkernel, padding='same')(x)
            x = tf.keras.layers.Conv2D(n_hidden_2, convkernel, activation='relu', padding='same')(x)
            x = tf.keras.layers.MaxPooling2D(poolkernel, padding='same')(x)
            x = tf.keras.layers.Conv2D(n_hidden_3, convkernel, activation='relu', padding='same')(x)
            encoded = tf.keras.layers.MaxPooling2D(poolkernel, padding='same')(x)

            x = tf.keras.layers.Conv2D(n_hidden_3, convkernel, activation='relu', padding='same')(encoded)
            x = tf.keras.layers.UpSampling2D(poolkernel)(x)
            x = tf.keras.layers.Conv2D(n_hidden_2, convkernel, activation='relu', padding='same')(x)
            x = tf.keras.layers.UpSampling2D(poolkernel)(x)
            x = tf.keras.layers.Conv2D(n_hidden_1, convkernel, activation='relu')(x)
            x = tf.keras.layers.UpSampling2D(poolkernel)(x)
            decoded = tf.keras.layers.Conv2D(shape_img[2], convkernel, activation='sigmoid', padding='same')(x)

        else:
            raise Exception("Invalid model name given!")

        # Create autoencoder model
        autoencoder = tf.keras.Model(input, decoded)
        input_autoencoder_shape = autoencoder.layers[0].input_shape[1:]
        output_autoencoder_shape = autoencoder.layers[-1].output_shape[1:]

        # Create encoder model
        encoder = tf.keras.Model(input, encoded)  # set encoder
        input_encoder_shape = encoder.layers[0].input_shape[1:]
        output_encoder_shape = encoder.layers[-1].output_shape[1:]

        # Create decoder model
        decoded_input = tf.keras.Input(shape=output_encoder_shape)
        if self.modelName == 'simpleAE':
            decoded_output = autoencoder.layers[-1](decoded_input)  # single layer
        elif self.modelName == 'convAE':
            decoded_output = autoencoder.layers[-7](decoded_input)  # Conv2D
            decoded_output = autoencoder.layers[-6](decoded_output)  # UpSampling2D
            decoded_output = autoencoder.layers[-5](decoded_output)  # Conv2D
            decoded_output = autoencoder.layers[-4](decoded_output)  # UpSampling2D
            decoded_output = autoencoder.layers[-3](decoded_output)  # Conv2D
            decoded_output = autoencoder.layers[-2](decoded_output)  # UpSampling2D
            decoded_output = autoencoder.layers[-1](decoded_output)  # Conv2D
        else:
            raise Exception("Invalid model name given!")
        decoder = tf.keras.Model(decoded_input, decoded_output)
        decoder_input_shape = decoder.layers[0].input_shape[1:]
        decoder_output_shape = decoder.layers[-1].output_shape[1:]

        # Generate summaries
        print("\nautoencoder.summary():")
        print(autoencoder.summary())
        print("\nencoder.summary():")
        print(encoder.summary())
        print("\ndecoder.summary():")
        print(decoder.summary())

        # Assign models
        self.autoencoder = autoencoder
        self.encoder = encoder
        self.decoder = decoder

    # Compile
    def compile(self, loss="binary_crossentropy", optimizer="adam"):
        self.autoencoder.compile(optimizer=optimizer, loss=loss)

    # Load model architecture and weights
    def load_models(self, loss="binary_crossentropy", optimizer="adam"):
        print("Loading models...")
        self.autoencoder = tf.keras.models.load_model(self.info["autoencoderFile"])
        self.encoder = tf.keras.models.load_model(self.info["encoderFile"])
        self.decoder = tf.keras.models.load_model(self.info["decoderFile"])
        self.autoencoder.compile(optimizer=optimizer, loss=loss)
        self.encoder.compile(optimizer=optimizer, loss=loss)
        self.decoder.compile(optimizer=optimizer, loss=loss)

    # Save model architecture and weights to file
    def save_models(self):
        print("Saving models...")
        self.autoencoder.save(self.info["autoencoderFile"])
        self.encoder.save(self.info["encoderFile"])
        self.decoder.save(self.info["decoderFile"])
        
"""
 utils.py (author: Anson Wong / git: ankonzoid)
"""
import random
import numpy as np

# Get split indices
def split(fracs, N, seed):
    fracs = [round(frac, 2) for frac in fracs]
    if sum(fracs) != 1.00:
        raise Exception("fracs do not sum to one!")

    # Shuffle ordered indices
    indices = list(range(N))
    random.Random(seed).shuffle(indices)
    indices = np.array(indices, dtype=int)

    # Get numbers per group
    n_fracs = []
    for i in range(len(fracs) - 1):
        n_fracs.append(int(max(fracs[i] * N, 0)))
    n_fracs.append(int(max(N - sum(n_fracs), 0)))

    if sum(n_fracs) != N:
        raise Exception("n_fracs do not sum to N!")

    # Sample indices
    n_selected = 0
    indices_fracs = []
    for n_frac in n_fracs:
        indices_frac = indices[n_selected:n_selected + n_frac]
        indices_fracs.append(indices_frac)
        n_selected += n_frac

    # Check no intersections
    for a, indices_frac_A in enumerate(indices_fracs):
        for b, indices_frac_B in enumerate(indices_fracs):
            if a == b:
                continue
            if is_intersect(indices_frac_A, indices_frac_B):
                raise Exception("there are intersections!")

    return indices_fracs

# Is there intersection?
def is_intersect(arr1, arr2):
    n_intersect = len(np.intersect1d(arr1, arr2))
    if n_intersect == 0: return False
    else: return True

# %%
"""
 image_retrieval.py  (author: Anson Wong / git: ankonzoid)
 We perform image retrieval using transfer learning on a pre-trained
 VGG image classifier. We plot the k=5 most similar images to our
 query images, as well as the t-SNE visualizations.
"""
import os
import numpy as np
import tensorflow as tf
from sklearn.neighbors import NearestNeighbors


# Run mode: (autoencoder -> simpleAE, convAE) or (transfer learning -> vgg19)
modelName = "convAE"  # try: "simpleAE", "convAE", "vgg19"
trainModel = True
parallel = True  # use multicore processing

# Make paths
#dataTrainDir = os.path.join(os.getcwd(), "data", "train")
#dataTestDir = os.path.join(os.getcwd(), "data", "test")
outDir = os.path.join(os.getcwd(), "output", modelName)
##if not os.path.exists(outDir):
#    os.makedirs(outDir)

# Read images
extensions = [".jpg", ".jpeg"]
#print("Reading train images from '{}'...".format(dataTrainDir))
#imgs_train = read_imgs_dir(dataTrainDir, extensions, parallel=parallel)
#print("Reading test images from '{}'...".format(dataTestDir))
#imgs_test = read_imgs_dir(dataTestDir, extensions, parallel=parallel)
#shape_img = imgs_train[0].shape
#print("Image shape = {}".format(shape_img))

imgs_train = imgs

shape_img = imgs_train[0].shape
print("Image shape = {}".format(shape_img))

# Build models
if modelName in ["simpleAE", "convAE"]:

    # Set up autoencoder
    info = {
        "shape_img": shape_img,
        "autoencoderFile": os.path.join(outDir, "{}_autoecoder.h5".format(modelName)),
        "encoderFile": os.path.join(outDir, "{}_encoder.h5".format(modelName)),
        "decoderFile": os.path.join(outDir, "{}_decoder.h5".format(modelName)),
    }
    model = AutoEncoder(modelName, info)
    model.set_arch()

    if modelName == "simpleAE":
        shape_img_resize = shape_img
        input_shape_model = (model.encoder.input.shape[1],)
        output_shape_model = (model.encoder.output.shape[1],)
        n_epochs = 300
    elif modelName == "convAE":
        shape_img_resize = shape_img
        input_shape_model = tuple([int(x) for x in model.encoder.input.shape[1:]])
        output_shape_model = tuple([int(x) for x in model.encoder.output.shape[1:]])
        n_epochs = 500
    else:
        raise Exception("Invalid modelName!")

elif modelName in ["vgg19"]:

    # Load pre-trained VGG19 model + higher level layers
    print("Loading VGG19 pre-trained model...")
    model = tf.keras.applications.VGG19(weights='imagenet', include_top=False,
                                        input_shape=shape_img)
    model.summary()

    shape_img_resize = tuple([int(x) for x in model.input.shape[1:]])
    input_shape_model = tuple([int(x) for x in model.input.shape[1:]])
    output_shape_model = tuple([int(x) for x in model.output.shape[1:]])
    n_epochs = None

else:
    raise Exception("Invalid modelName!")

# Print some model info
print("input_shape_model = {}".format(input_shape_model))
print("output_shape_model = {}".format(output_shape_model))

# Apply transformations to all images
class ImageTransformer(object):

    def __init__(self, shape_resize):
        self.shape_resize = shape_resize

    def __call__(self, img):
        img_transformed = resize_img(img, self.shape_resize)
        img_transformed = normalize_img(img_transformed)
        return img_transformed

transformer = ImageTransformer(shape_img_resize)
print("Applying image transformer to training images...")
imgs_train_transformed = apply_transformer(imgs_train, transformer, parallel=parallel)
print("Applying image transformer to test images...")
#imgs_test_transformed = apply_transformer(imgs_test, transformer, parallel=parallel)

# Convert images to numpy array
X_train = np.array(imgs_train_transformed).reshape((-1,) + input_shape_model)
print(".........")
print(X_train.shape)
X_test = X_train[70:] #np.array(imgs_test_transformed).reshape((-1,) + input_shape_model)
print(" -> X_train.shape = {}".format(X_train.shape))
print(" -> X_test.shape = {}".format(X_test.shape))

# Train (if necessary)
if modelName in ["simpleAE", "convAE"]:
    if trainModel:
        model.compile(loss="binary_crossentropy", optimizer="adam")
        model.fit(X_train, n_epochs=n_epochs, batch_size=256)
        model.save_models()
    else:
        model.load_models(loss="binary_crossentropy", optimizer="adam")

# Create embeddings using model
print("Inferencing embeddings using pre-trained model...")
E_train = model.predict(X_train)
E_train_flatten = E_train.reshape((-1, np.prod(output_shape_model)))
E_test = model.predict(X_test)
E_test_flatten = E_test.reshape((-1, np.prod(output_shape_model)))
print(" -> E_train.shape = {}".format(E_train.shape))
print(" -> E_test.shape = {}".format(E_test.shape))
print(" -> E_train_flatten.shape = {}".format(E_train_flatten.shape))
print(" -> E_test_flatten.shape = {}".format(E_test_flatten.shape))

# Make reconstruction visualizations
if modelName in ["simpleAE", "convAE"]:
    print("Visualizing database image reconstructions...")
    imgs_train_reconstruct = model.decoder.predict(E_train)
    if modelName == "simpleAE":
        imgs_train_reconstruct = imgs_train_reconstruct.reshape((-1,) + shape_img_resize)
    plot_reconstructions(imgs_train, imgs_train_reconstruct,
                         os.path.join(outDir, "{}_reconstruct.png".format(modelName)),
                         range_imgs=[0, 255],
                         range_imgs_reconstruct=[0, 1])

# Fit kNN model on training images
print("Fitting k-nearest-neighbour model on training images...")
knn = NearestNeighbors(n_neighbors=5, metric="cosine")
knn.fit(E_train_flatten)
# Out:
# Image shape = (100, 100, 3)
#
# autoencoder.summary():
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 50, 50, 8)         1160
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 25, 25, 8)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 25, 25, 8)         584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 13, 13, 8)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 13, 13, 8)         584
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 26, 26, 8)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 26, 26, 8)         584
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 52, 52, 8)         0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 50, 50, 16)        1168
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 100, 100, 3)       435
# =================================================================
# Total params: 4,963
# Trainable params: 4,963
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# encoder.summary():
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 50, 50, 8)         1160
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 25, 25, 8)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 25, 25, 8)         584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 13, 13, 8)         0
# =================================================================
# Total params: 2,192
# Trainable params: 2,192
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# decoder.summary():
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 13, 13, 8)]       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 13, 13, 8)         584
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 26, 26, 8)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 26, 26, 8)         584
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 52, 52, 8)         0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 50, 50, 16)        1168
# _________________________________________________________________
# up_sampling2d_11 (UpSampling (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 100, 100, 3)       435
# =================================================================
# Total params: 2,771
# Trainable params: 2,771
# Non-trainable params: 0
# _________________________________________________________________
# None
# input_shape_model = (100, 100, 3)
# output_shape_model = (13, 13, 8)
# Applying image transformer to training images...
# Applying image transformer to test images...
# .........
# (97, 100, 100, 3)
#  -> X_train.shape = (97, 100, 100, 3)
#  -> X_test.shape = (27, 100, 100, 3)
# Train on 87 samples, validate on 10 samples
# Epoch 1/500
# 87/87 [==============================] - 1s 10ms/sample - loss: 0.6931 - val_loss: 0.6915
# Epoch 2/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6915 - val_loss: 0.6895
# Epoch 3/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6895 - val_loss: 0.6872
# Epoch 4/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6872 - val_loss: 0.6847
# Epoch 5/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6847 - val_loss: 0.6819
# Epoch 6/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6819 - val_loss: 0.6787
# Epoch 7/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6787 - val_loss: 0.6751
# Epoch 8/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6751 - val_loss: 0.6709
# Epoch 9/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.6709 - val_loss: 0.6662
# Epoch 10/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6662 - val_loss: 0.6607
# Epoch 11/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6607 - val_loss: 0.6544
# Epoch 12/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6544 - val_loss: 0.6471
# Epoch 13/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6471 - val_loss: 0.6386
# Epoch 14/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6386 - val_loss: 0.6287
# Epoch 15/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6287 - val_loss: 0.6171
# Epoch 16/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6171 - val_loss: 0.6036
# Epoch 17/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.6036 - val_loss: 0.5878
# Epoch 18/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.5878 - val_loss: 0.5695
# Epoch 19/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.5694 - val_loss: 0.5483
# Epoch 20/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.5482 - val_loss: 0.5239
# Epoch 21/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.5238 - val_loss: 0.4960
# Epoch 22/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.4959 - val_loss: 0.4644
# Epoch 23/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.4643 - val_loss: 0.4291
# Epoch 24/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.4290 - val_loss: 0.3902
# Epoch 25/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.3900 - val_loss: 0.3480
# Epoch 26/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.3479 - val_loss: 0.3035
# Epoch 27/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.3033 - val_loss: 0.2577
# Epoch 28/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.2575 - val_loss: 0.2121
# Epoch 29/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.2119 - val_loss: 0.1688
# Epoch 30/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.1687 - val_loss: 0.1298
# Epoch 31/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.1298 - val_loss: 0.0970
# Epoch 32/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0970 - val_loss: 0.0713
# Epoch 33/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0713 - val_loss: 0.0525
# Epoch 34/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0526 - val_loss: 0.0400
# Epoch 35/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0403 - val_loss: 0.0326
# Epoch 36/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0329 - val_loss: 0.0287
# Epoch 37/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0291 - val_loss: 0.0273
# Epoch 38/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0277 - val_loss: 0.0273
# Epoch 39/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0279 - val_loss: 0.0282
# Epoch 40/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0289 - val_loss: 0.0296
# Epoch 41/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0303 - val_loss: 0.0313
# Epoch 42/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0320 - val_loss: 0.0329
# Epoch 43/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0337 - val_loss: 0.0345
# Epoch 44/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0353 - val_loss: 0.0359
# Epoch 45/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0368 - val_loss: 0.0372
# Epoch 46/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0381 - val_loss: 0.0383
# Epoch 47/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0392 - val_loss: 0.0391
# Epoch 48/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0401 - val_loss: 0.0398
# Epoch 49/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0408 - val_loss: 0.0402
# Epoch 50/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0412 - val_loss: 0.0405
# Epoch 51/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0415 - val_loss: 0.0405
# Epoch 52/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0416 - val_loss: 0.0404
# Epoch 53/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0415 - val_loss: 0.0402
# Epoch 54/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0412 - val_loss: 0.0399
# Epoch 55/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0409 - val_loss: 0.0394
# Epoch 56/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0404 - val_loss: 0.0389
# Epoch 57/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0399 - val_loss: 0.0383
# Epoch 58/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0393 - val_loss: 0.0377
# Epoch 59/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0386 - val_loss: 0.0370
# Epoch 60/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0379 - val_loss: 0.0363
# Epoch 61/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0372 - val_loss: 0.0356
# Epoch 62/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0364 - val_loss: 0.0348
# Epoch 63/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0357 - val_loss: 0.0341
# Epoch 64/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0349 - val_loss: 0.0333
# Epoch 65/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0342 - val_loss: 0.0326
# Epoch 66/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0334 - val_loss: 0.0319
# Epoch 67/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0327 - val_loss: 0.0312
# Epoch 68/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0320 - val_loss: 0.0305
# Epoch 69/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0313 - val_loss: 0.0299
# Epoch 70/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0306 - val_loss: 0.0293
# Epoch 71/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0300 - val_loss: 0.0287
# Epoch 72/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0294 - val_loss: 0.0282
# Epoch 73/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0289 - val_loss: 0.0278
# Epoch 74/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0284 - val_loss: 0.0273
# Epoch 75/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0280 - val_loss: 0.0270
# Epoch 76/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0276 - val_loss: 0.0266
# Epoch 77/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0272 - val_loss: 0.0263
# Epoch 78/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0269 - val_loss: 0.0261
# Epoch 79/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0266 - val_loss: 0.0259
# Epoch 80/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0264 - val_loss: 0.0257
# Epoch 81/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0262 - val_loss: 0.0256
# Epoch 82/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0261 - val_loss: 0.0255
# Epoch 83/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0260 - val_loss: 0.0254
# Epoch 84/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0259 - val_loss: 0.0254
# Epoch 85/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0259 - val_loss: 0.0253
# Epoch 86/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0258 - val_loss: 0.0253
# Epoch 87/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0258 - val_loss: 0.0253
# Epoch 88/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0258 - val_loss: 0.0253
# Epoch 89/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0257 - val_loss: 0.0252
# Epoch 90/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0257 - val_loss: 0.0252
# Epoch 91/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0256 - val_loss: 0.0251
# Epoch 92/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0256 - val_loss: 0.0251
# Epoch 93/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0255 - val_loss: 0.0250
# Epoch 94/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0255 - val_loss: 0.0250
# Epoch 95/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0255 - val_loss: 0.0249
# Epoch 96/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0254 - val_loss: 0.0249
# Epoch 97/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0254 - val_loss: 0.0248
# Epoch 98/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0253 - val_loss: 0.0248
# Epoch 99/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0253 - val_loss: 0.0248
# Epoch 100/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0252 - val_loss: 0.0247
# Epoch 101/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0252 - val_loss: 0.0246
# Epoch 102/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0251 - val_loss: 0.0246
# Epoch 103/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0251 - val_loss: 0.0245
# Epoch 104/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0250 - val_loss: 0.0245
# Epoch 105/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0249 - val_loss: 0.0244
# Epoch 106/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0249 - val_loss: 0.0243
# Epoch 107/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0248 - val_loss: 0.0243
# Epoch 108/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0248 - val_loss: 0.0243
# Epoch 109/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0247 - val_loss: 0.0242
# Epoch 110/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0247 - val_loss: 0.0242
# Epoch 111/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0247 - val_loss: 0.0241
# Epoch 112/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0246 - val_loss: 0.0241
# Epoch 113/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0246 - val_loss: 0.0240
# Epoch 114/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0245 - val_loss: 0.0240
# Epoch 115/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0245 - val_loss: 0.0240
# Epoch 116/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0244 - val_loss: 0.0239
# Epoch 117/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0244 - val_loss: 0.0239
# Epoch 118/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0244 - val_loss: 0.0239
# Epoch 119/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0244 - val_loss: 0.0238
# Epoch 120/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0243 - val_loss: 0.0238
# Epoch 121/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0243 - val_loss: 0.0238
# Epoch 122/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0243 - val_loss: 0.0237
# Epoch 123/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0242 - val_loss: 0.0237
# Epoch 124/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0242 - val_loss: 0.0237
# Epoch 125/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0242 - val_loss: 0.0236
# Epoch 126/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0241 - val_loss: 0.0236
# Epoch 127/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0241 - val_loss: 0.0235
# Epoch 128/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0240 - val_loss: 0.0235
# Epoch 129/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0240 - val_loss: 0.0234
# Epoch 130/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0239 - val_loss: 0.0234
# Epoch 131/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0239 - val_loss: 0.0233
# Epoch 132/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0238 - val_loss: 0.0233
# Epoch 133/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0238 - val_loss: 0.0233
# Epoch 134/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0237 - val_loss: 0.0232
# Epoch 135/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0237 - val_loss: 0.0232
# Epoch 136/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0237 - val_loss: 0.0231
# Epoch 137/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0236 - val_loss: 0.0231
# Epoch 138/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0236 - val_loss: 0.0231
# Epoch 139/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0235 - val_loss: 0.0231
# Epoch 140/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0235 - val_loss: 0.0230
# Epoch 141/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0235 - val_loss: 0.0230
# Epoch 142/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0235 - val_loss: 0.0230
# Epoch 143/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0234 - val_loss: 0.0229
# Epoch 144/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0234 - val_loss: 0.0229
# Epoch 145/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0234 - val_loss: 0.0229
# Epoch 146/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0233 - val_loss: 0.0228
# Epoch 147/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0233 - val_loss: 0.0228
# Epoch 148/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0233 - val_loss: 0.0228
# Epoch 149/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0233 - val_loss: 0.0228
# Epoch 150/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0232 - val_loss: 0.0227
# Epoch 151/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0232 - val_loss: 0.0227
# Epoch 152/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0232 - val_loss: 0.0227
# Epoch 153/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0232 - val_loss: 0.0227
# Epoch 154/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0231 - val_loss: 0.0227
# Epoch 155/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0231 - val_loss: 0.0226
# Epoch 156/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0231 - val_loss: 0.0226
# Epoch 157/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0231 - val_loss: 0.0226
# Epoch 158/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0231 - val_loss: 0.0226
# Epoch 159/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0230 - val_loss: 0.0226
# Epoch 160/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0230 - val_loss: 0.0225
# Epoch 161/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0230 - val_loss: 0.0225
# Epoch 162/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0230 - val_loss: 0.0225
# Epoch 163/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0230 - val_loss: 0.0225
# Epoch 164/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0230 - val_loss: 0.0225
# Epoch 165/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0230 - val_loss: 0.0225
# Epoch 166/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0225
# Epoch 167/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0225
# Epoch 168/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 169/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 170/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 171/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 172/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 173/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 174/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 175/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 176/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 177/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 178/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 179/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 180/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0229 - val_loss: 0.0224
# Epoch 181/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0224
# Epoch 182/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0224
# Epoch 183/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0224
# Epoch 184/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0224
# Epoch 185/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0224
# Epoch 186/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0224
# Epoch 187/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0224
# Epoch 188/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0224
# Epoch 189/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0224
# Epoch 190/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 191/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 192/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 193/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 194/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 195/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 196/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 197/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 198/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 199/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 200/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 201/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 202/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 203/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 204/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 205/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 206/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 207/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 208/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 209/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 210/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 211/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 212/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 213/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 214/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 215/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 216/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 217/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 218/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0228 - val_loss: 0.0223
# Epoch 219/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 220/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 221/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 222/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 223/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 224/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 225/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 226/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 227/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 228/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 229/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 230/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 231/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 232/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 233/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 234/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 235/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 236/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 237/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 238/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 239/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 240/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 241/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 242/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 243/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 244/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 245/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 246/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0223
# Epoch 247/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 248/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 249/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 250/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 251/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 252/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 253/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 254/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 255/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 256/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 257/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 258/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 259/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 260/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 261/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 262/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 263/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 264/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 265/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 266/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 267/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 268/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 269/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 270/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 271/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 272/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 273/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 274/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 275/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 276/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 277/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 278/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 279/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 280/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 281/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 282/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 283/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 284/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 285/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 286/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 287/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 288/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 289/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 290/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 291/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 292/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 293/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 294/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 295/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 296/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 297/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 298/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 299/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 300/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 301/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 302/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 303/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 304/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 305/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 306/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 307/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 308/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 309/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 310/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 311/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 312/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 313/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 314/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 315/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 316/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 317/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 318/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 319/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 320/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 321/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 322/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 323/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 324/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 325/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 326/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 327/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 328/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 329/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 330/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 331/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 332/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 333/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 334/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 335/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 336/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 337/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 338/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 339/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 340/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 341/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 342/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 343/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 344/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 345/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 346/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 347/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 348/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 349/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 350/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 351/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 352/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 353/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 354/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 355/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 356/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 357/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 358/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 359/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 360/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 361/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 362/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 363/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 364/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 365/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 366/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 367/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 368/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 369/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 370/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 371/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 372/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 373/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 374/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 375/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 376/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 377/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 378/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 379/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 380/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 381/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 382/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 383/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 384/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 385/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 386/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 387/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 388/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 389/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 390/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 391/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 392/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 393/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 394/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0222
# Epoch 395/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 396/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 397/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 398/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 399/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 400/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 401/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 402/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 403/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 404/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 405/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 406/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 407/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 408/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 409/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 410/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 411/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 412/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 413/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 414/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 415/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 416/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 417/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 418/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 419/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 420/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 421/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 422/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 423/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 424/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 425/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 426/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 427/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 428/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 429/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 430/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 431/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 432/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 433/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 434/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 435/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 436/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 437/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 438/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 439/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 440/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 441/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 442/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 443/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 444/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 445/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 446/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 447/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 448/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 449/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 450/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 451/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 452/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 453/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 454/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 455/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 456/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 457/500
# 87/87 [==============================] - 0s 5ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 458/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 459/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 460/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 461/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 462/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 463/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 464/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 465/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 466/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 467/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 468/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 469/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 470/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 471/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 472/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 473/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 474/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 475/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 476/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 477/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 478/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 479/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 480/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 481/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 482/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 483/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 484/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 485/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 486/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 487/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 488/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 489/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 490/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 491/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 492/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 493/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 494/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 495/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 496/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 497/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 498/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 499/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Epoch 500/500
# 87/87 [==============================] - 0s 4ms/sample - loss: 0.0226 - val_loss: 0.0221
# Saving models...
# Inferencing embeddings using pre-trained model...
#  -> E_train.shape = (97, 13, 13, 8)
#  -> E_test.shape = (27, 13, 13, 8)
#  -> E_train_flatten.shape = (97, 1352)
#  -> E_test_flatten.shape = (27, 1352)
# Visualizing database image reconstructions...
# Fitting k-nearest-neighbour model on training images...
# Performing image retrieval on test images...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-dfebe3c53b49> in <module>
#     148 for i, emb_flatten in enumerate(E_test_flatten):
#     149     _, indices = knn.kneighbors([emb_flatten]) # find k nearest train neighbours
# --> 150     img_query = imgs_test[i] # query image
#     151     imgs_retrieval = [imgs_train[idx] for idx in indices.flatten()] # retrieval images
#     152     outFile = os.path.join(outDir, "{}_retrieval_{}.png".format(modelName, i))
#
# NameError: name 'imgs_test' is not defined

# %%
# Perform image retrieval on test images
imgs_test = imgs[71:]
print("Performing image retrieval on test images...")
for i, emb_flatten in enumerate(E_test_flatten):
    _, indices = knn.kneighbors([emb_flatten]) # find k nearest train neighbours
    img_query = imgs_test[i] # query image
    imgs_retrieval = [imgs_train[idx] for idx in indices.flatten()] # retrieval images
    outFile = os.path.join(outDir, "{}_retrieval_{}.png".format(modelName, i))
    plot_query_retrieval(img_query, imgs_retrieval, outFile)

# Plot t-SNE visualization
print("Visualizing t-SNE on training images...")
outFile = os.path.join(outDir, "{}_tsne.png".format(modelName))
plot_tsne(E_train_flatten, imgs_train, outFile)
# Out:
# Performing image retrieval on test images...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-1e878abcdbe9> in <module>
#       4 for i, emb_flatten in enumerate(E_test_flatten):
#       5     _, indices = knn.kneighbors([emb_flatten]) # find k nearest train neighbours
# ----> 6     img_query = imgs_test[i] # query image
#       7     imgs_retrieval = [imgs_train[idx] for idx in indices.flatten()] # retrieval images
#       8     outFile = os.path.join(outDir, "{}_retrieval_{}.png".format(modelName, i))
#
# IndexError: index 26 is out of bounds for axis 0 with size 26

# %%
# %mkdir output

# %%
# %mkdir output/convAE

# %%
# !pip install exif
# Out:
# Collecting exif
#   Downloading https://files.pythonhosted.org/packages/f6/e0/a0213d9f0484ba4d426080ee5fc793b0711b4adc5d8ad3876b1c61abc909/exif-0.8.1-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 32kB/s eta 0:00:01
# Collecting enum34 (from exif)
#   Downloading https://files.pythonhosted.org/packages/af/42/cb9355df32c69b553e72a2e28daee25d1611d2c0d9c272aa1d34204205b2/enum34-1.1.6-py3-none-any.whl
# Installing collected packages: enum34, exif
# Successfully installed enum34-1.1.6 exif-0.8.1

# %%
from exif import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-47-69f4c9c28c92> in <module>
# ----> 1 from exif import Image
#
# ModuleNotFoundError: No module named 'exif'

# %%
>>> with open('grand_canyon.jpg', 'rb') as image_file:
...     my_image = Image(image_file)
...
>>> my_image.has_exif
True
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-fe2a5e2476ee> in <module>
#       3 exif = {
#       4     PIL.ExifTags.TAGS[k]: v
# ----> 5     for k, v in img._getexif().items()
#       6     if k in PIL.ExifTags.TAGS
#       7 }
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
sample[-1]
# Out:
# '/home/actas/770901.jpg'

# %%
import PIL.Image
img = PIL.Image.open(sample[10])
exif_data = img._getexif()

print(exif_data)
# Out:
# None
